# %%
from data import Stock
import pandas as pd
from analysis import Analysis
from hidden_markov_model import Hidden_Markov_Model

# %%
sa40 = Stock('JTOPI')
sa40.series_data = pd.read_csv('South_Africa_Top_40_Historical_Data.csv')
sa40.preprocess()

analysis = Analysis()
analysis.add_log_return(sa40)
sa40.series_data.dropna(inplace=True)

model = Hidden_Markov_Model(sa40.series_data['Log_Return'].to_numpy(), 4)

# %%
model.baum_welch_algorithm(0.005, 100)
# Out:
# Iteration 1 . . . Log-Likelihood = 3829.6420508493657
# Iteration 2 . . . Log-Likelihood = 3829.9411356462215
# Iteration 3 . . . Log-Likelihood = 3844.355858249328
# Iteration 4 . . . Log-Likelihood = 3933.237597020923
# Iteration 5 . . . Log-Likelihood = 3972.685396491744
# Iteration 6 . . . Log-Likelihood = 3980.337813456823
# Iteration 7 . . . Log-Likelihood = 3984.732300232547
# Iteration 8 . . . Log-Likelihood = 3987.8037178246477
# Iteration 9 . . . Log-Likelihood = 3990.143001943477
# Iteration 10 . . . Log-Likelihood = 3992.0573894064564
# Iteration 11 . . . Log-Likelihood = 3993.6599181158635
# Iteration 12 . . . Log-Likelihood = 3994.969862148606
# Iteration 13 . . . Log-Likelihood = 3996.0025405579017
# Iteration 14 . . . Log-Likelihood = 3996.820398379037
# Iteration 15 . . . Log-Likelihood = 3997.500940030626
# Iteration 16 . . . Log-Likelihood = 3998.097329131251
# Iteration 17 . . . Log-Likelihood = 3998.6352411934877
# Iteration 18 . . . Log-Likelihood = 3999.1262848374845
# Iteration 19 . . . Log-Likelihood = 3999.577397131908
# Iteration 20 . . . Log-Likelihood = 3999.9934432035475
# Iteration 21 . . . Log-Likelihood = 4000.378303999694
# Iteration 22 . . . Log-Likelihood = 4000.7362580779954
# Iteration 23 . . . Log-Likelihood = 4001.0727867344604
# Iteration 24 . . . Log-Likelihood = 4001.3944458925343
# Iteration 25 . . . Log-Likelihood = 4001.708248959167
# Iteration 26 . . . Log-Likelihood = 4002.0211165657065
# Iteration 27 . . . Log-Likelihood = 4002.3397005524475
# Iteration 28 . . . Log-Likelihood = 4002.6706636415533
# Iteration 29 . . . Log-Likelihood = 4003.021431728959
# Iteration 30 . . . Log-Likelihood = 4003.4015067436494
# Iteration 31 . . . Log-Likelihood = 4003.82450982901
# Iteration 32 . . . Log-Likelihood = 4004.3108064873913
# Iteration 33 . . . Log-Likelihood = 4004.8886794396713
# Iteration 34 . . . Log-Likelihood = 4005.5882643267378
# Iteration 35 . . . Log-Likelihood = 4006.4263214054668
# Iteration 36 . . . Log-Likelihood = 4007.392837809825
# Iteration 37 . . . Log-Likelihood = 4008.427331974603
# Iteration 38 . . . Log-Likelihood = 4009.4232831038785
# Iteration 39 . . . Log-Likelihood = 4010.3394920570545
# Iteration 40 . . . Log-Likelihood = 4011.2120351760123
# Iteration 41 . . . Log-Likelihood = 4012.07315330685
# Iteration 42 . . . Log-Likelihood = 4012.933569409815
# Iteration 43 . . . Log-Likelihood = 4013.7923883002504
# Iteration 44 . . . Log-Likelihood = 4014.644211726025
# Iteration 45 . . . Log-Likelihood = 4015.4824196164764
# Iteration 46 . . . Log-Likelihood = 4016.300484638141
# Iteration 47 . . . Log-Likelihood = 4017.0923738219344
# Iteration 48 . . . Log-Likelihood = 4017.8525900585223
# Iteration 49 . . . Log-Likelihood = 4018.5761533908208
# Iteration 50 . . . Log-Likelihood = 4019.2586609299456
# Iteration 51 . . . Log-Likelihood = 4019.8964539853937
# Iteration 52 . . . Log-Likelihood = 4020.4868533013127
# Iteration 53 . . . Log-Likelihood = 4021.0283911560336
# Iteration 54 . . . Log-Likelihood = 4021.520966090651
# Iteration 55 . . . Log-Likelihood = 4021.965866430086
# Iteration 56 . . . Log-Likelihood = 4022.365644315899
# Iteration 57 . . . Log-Likelihood = 4022.7238606666856
# Iteration 58 . . . Log-Likelihood = 4023.0447506327237
# Iteration 59 . . . Log-Likelihood = 4023.3328705762096
# Iteration 60 . . . Log-Likelihood = 4023.5927809135997
# Iteration 61 . . . Log-Likelihood = 4023.828800410619
# Iteration 62 . . . Log-Likelihood = 4024.0448453769664
# Iteration 63 . . . Log-Likelihood = 4024.244348767051
# Iteration 64 . . . Log-Likelihood = 4024.4302429257073
# Iteration 65 . . . Log-Likelihood = 4024.6049856509057
# Iteration 66 . . . Log-Likelihood = 4024.7706103987293
# Iteration 67 . . . Log-Likelihood = 4024.928785363869
# Iteration 68 . . . Log-Likelihood = 4025.0808708454406
# Iteration 69 . . . Log-Likelihood = 4025.227968575307
# Iteration 70 . . . Log-Likelihood = 4025.3709600851744
# Iteration 71 . . . Log-Likelihood = 4025.510533720215
# Iteration 72 . . . Log-Likelihood = 4025.6472017667984
# Iteration 73 . . . Log-Likelihood = 4025.781310539603
# Iteration 74 . . . Log-Likelihood = 4025.9130472306524
# Iteration 75 . . . Log-Likelihood = 4026.0424477593992
# Iteration 76 . . . Log-Likelihood = 4026.1694095756156
# Iteration 77 . . . Log-Likelihood = 4026.2937121960704
# Iteration 78 . . . Log-Likelihood = 4026.4150462666876
# Iteration 79 . . . Log-Likelihood = 4026.5330495364688
# Iteration 80 . . . Log-Likelihood = 4026.6473459865383
# Iteration 81 . . . Log-Likelihood = 4026.757583178197
# Iteration 82 . . . Log-Likelihood = 4026.8634630635324
# Iteration 83 . . . Log-Likelihood = 4026.964762930522
# Iteration 84 . . . Log-Likelihood = 4027.0613452745247
# Iteration 85 . . . Log-Likelihood = 4027.15315747464
# Iteration 86 . . . Log-Likelihood = 4027.240223633019
# Iteration 87 . . . Log-Likelihood = 4027.322631568829
# Iteration 88 . . . Log-Likelihood = 4027.4005178326615
# Iteration 89 . . . Log-Likelihood = 4027.4740529959945
# Iteration 90 . . . Log-Likelihood = 4027.543428678407
# Iteration 91 . . . Log-Likelihood = 4027.608847032971
# Iteration 92 . . . Log-Likelihood = 4027.6705128406074
# Iteration 93 . . . Log-Likelihood = 4027.7286279983255
# Iteration 94 . . . Log-Likelihood = 4027.7833879993727
# Iteration 95 . . . Log-Likelihood = 4027.834979947008
# Iteration 96 . . . Log-Likelihood = 4027.883581668517
# Iteration 97 . . . Log-Likelihood = 4027.929361562309
# Iteration 98 . . . Log-Likelihood = 4027.9724788909384
# Iteration 99 . . . Log-Likelihood = 4028.0130843101715
# Iteration 100 . . . Log-Likelihood = 4028.051320490606

# %%
model.get_parameters()
# Out:
# ==================================== 0 =====================================
# Initial Probability: 1.1260230626330466e-47
# Mean: 0.008949597563425572
# Variance: 0.00018025948856789767
#
#
# ==================================== 1 =====================================
# Initial Probability: 1.0
# Mean: 0.0005907776862441059
# Variance: 6.81579832274453e-05
#
#
# ==================================== 2 =====================================
# Initial Probability: 8.111253411503391e-49
# Mean: -0.009809872303703062
# Variance: 0.00013595851669550264
#
#
# ==================================== 3 =====================================
# Initial Probability: 1.1855801522301722e-196
# Mean: -0.004026538674780498
# Variance: 0.0016465545167821272
#
#
# Transition Matrix: [[5.66281164e-01 1.98372414e-01 2.35346421e-01 5.65191639e-20]
#  [1.87391112e-03 9.43946222e-01 5.18239398e-02 2.35592674e-03]
#  [5.07915528e-01 1.23867575e-02 4.79692879e-01 4.83614575e-06]
#  [4.80706544e-02 1.56311804e-26 3.00931093e-11 9.51929346e-01]]
# Log Likelihood: 4028.051320490606
